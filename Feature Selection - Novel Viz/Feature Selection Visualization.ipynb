# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("feature_selection.csv")
df.head()
# Out:
#      Operator Well Name Formation  Lateral Length  Stages  Township   Range  \
# 0  Operator 1    Well 1       MBH          5114.0    30.0        141     99
# 1  Operator 2    Well 2       MBH          5181.0     NaN        142     99
# 2  Operator 2    Well 3       MBH          4780.0    15.0        142     99
# 3  Operator 1    Well 4       MBH         10654.0     1.0        142     99
# 4  Operator 2    Well 5       MBH          5209.0     1.0        142     99
#
#    Section  Total Prop, lbs  Fluid, bbls  ... Best3 Mo BOPD  Best6 Mo BOPD  \
# 0       10              0.0      16079.0  ...    127.690116     110.009862
# 1       16         418000.0       7269.0  ...    127.832566      99.128863
# 2       24         568407.0       8279.0  ...     44.334867      36.905545
# 3        1         845000.0       9342.0  ...    120.764848      99.172693
# 4       35         297366.0       4523.0  ...    227.580539     189.869603
#
#    Best9 Mo BOPD  Best12 Mo BOPD  Compl. Type   Latitude   Longitude  \
# 0      97.351888       88.275258      No Data  47.051150 -103.214580
# 1      83.694938       72.019505      No Data  47.111368 -103.225059
# 2      31.766382       28.566732           OH  47.097032 -103.160910
# 3      86.675433       75.882095      No Data  47.140248 -103.178391
# 4     163.163854      140.033969           OH  47.080872 -103.181300
#
#    Fluid Type from DI  SPACING_CAPPED 12 month Cum Prod
# 0                 NaN           660.0             33.55
# 1                 NaN           660.0             27.62
# 2                 NaN           660.0             11.19
# 3                 NaN           660.0             27.85
# 4                 NaN           660.0             50.88
#
# [5 rows x 22 columns]

# %%
sns.relplot(x = 'Latitude', y = 'Longitude', hue = '12 month Cum Prod',data = df)

# %% [markdown]
# The production values are relatively higher around the middle of the graph, where the latitude is near 48.0 and the longitude is near -103.00

# %%
sns.relplot(x = "Total Prop, lbs", y = "12 month Cum Prod", data = df)

# %%
sns.relplot(x = "Lateral Length", y = "12 month Cum Prod", data = df)

# %%
sns.relplot(x = "Fluid, bbls", y = "12 month Cum Prod", data = df)

# %%
sns.relplot(x = "Stages", y = "12 month Cum Prod", data = df, kind = "line")

# %% [markdown]
# The production is at its highest when there are around 60 to 85 stages. It is at its lowest in the range 0 to 20 stages.

# %%
sns.relplot(x = "Section", y = "Range", hue = '12 month Cum Prod', data = df)

# %% [markdown]
# This graph does not show much, but the production is relatively higher when the range is near 90.

# %%
sns.relplot(x = "Section", y = "12 month Cum Prod", data = df, kind = "line")

# %%
sns.relplot(x = "Range", y = "12 month Cum Prod", data = df, kind = "line")

# %% [markdown]
# The range has a negative association with the oil production. As the range increases, the oil production decreases. Therefore, the lower the range, the more oil will be produced.

# %%
sns.relplot(x = "Operator", y = "12 month Cum Prod", data = df)

# %% [markdown]
# This graph shows the oil production of each operator. The lower number operators tend to have higher production values when comparing to the other operators.
